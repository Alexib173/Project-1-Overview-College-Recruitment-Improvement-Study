# %% [markdown]
# # Milestone #2: Final Project
#
# ## Begin the data analysis process of your final project by collecting your data and doing some initial exploratory analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/britocedeno.alexi/Downloads/JC-202507-citibike-tripdata.csv/JC-202507-citibike-tripdata.csv")

# %% [markdown]
# ### Here we examine the dimensions of the dataset and the data types of each column to understand what kind of cleaning might be required later

# %%
df.describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  107726.000000  107726.000000  107391.000000  107391.000000
# mean       40.732070     -74.040471      40.732049     -74.040171
# std         0.012367       0.012068       0.012410       0.012260
# min        40.706575     -74.086701      40.668132     -74.090000
# 25%        40.721124     -74.045953      40.721124     -74.045953
# 50%        40.734786     -74.038051      40.734786     -74.037977
# 75%        40.742258     -74.031600      40.742258     -74.031600
# max        40.754530     -74.024020      40.862562     -73.922661

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df.shape
# Out:
# (107726, 13)

# %% [markdown]
# ### We will look at the beginning, end, and a random sample of the dataset to verify the data loaded correctly and to spot any obvious inconsistencies.

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  8974E7FE6E43119D  electric_bike  2025-07-13 21:07:32.221
# 1  31EF8E5CBC2FA664  electric_bike  2025-07-10 19:02:28.736
# 2  F0FB644DB2CDEE04  electric_bike  2025-07-04 14:02:35.827
# 3  DB7BEA3FEC700AC5  electric_bike  2025-07-18 14:46:32.568
# 4  772B1CAA099E7DA5   classic_bike  2025-07-13 10:49:03.936
#
#                   ended_at                          start_station_name  \
# 0  2025-07-14 03:12:34.695                        Bergen Ave & Sip Ave
# 1  2025-07-10 19:19:43.664                  Stevens - River Ter & 6 St
# 2  2025-07-04 15:48:04.024                               Grove St PATH
# 3  2025-07-18 14:59:42.892           14 St Ferry - 14 St & Shipyard Ln
# 4  2025-07-14 11:48:59.171  Southwest Park - Jackson St & Observer Hwy
#
#   start_station_id end_station_name end_station_id  start_lat  start_lng  \
# 0            JC109              NaN            NaN  40.731009 -74.064437
# ...

# %%
df.tail()
# Out:
#                  ride_id  rideable_type               started_at  \
# 107721  76D8BC55B8366947  electric_bike  2025-07-17 10:32:57.303
# 107722  3B1DB8BF3F91E130   classic_bike  2025-07-07 09:25:01.626
# 107723  DDF8A86887F046B5   classic_bike  2025-07-15 08:19:39.912
# 107724  C6E827447B6089C6   classic_bike  2025-07-31 08:23:52.658
# 107725  50D9A1EECBD5FEEF  electric_bike  2025-07-25 09:52:58.011
#
#                        ended_at start_station_name start_station_id  \
# 107721  2025-07-17 10:37:59.005       Newport PATH            JC066
# 107722  2025-07-07 09:31:37.145       Newport PATH            JC066
# 107723  2025-07-15 08:27:15.668       Newport PATH            JC066
# 107724  2025-07-31 08:29:53.356       Newport PATH            JC066
# 107725  2025-07-25 09:57:50.344       Newport PATH            JC066
#
#        end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 107721         Grand St          JC102  40.727224 -74.033759  40.715178
# ...

# %%
df.sample()
# Out:
#                ride_id  rideable_type               started_at  \
# 7099  62ACD6810EE8B138  electric_bike  2025-07-16 19:09:44.828
#
#                      ended_at start_station_name start_station_id  \
# 7099  2025-07-16 19:15:30.252   Grand St & 14 St            HB506
#
#             end_station_name end_station_id  start_lat  start_lng   end_lat  \
# 7099  Clinton St & Newark St          HB409   40.75409   -74.0316  40.73743
#
#        end_lng member_casual
# 7099 -74.03571        member

# %% [markdown]
# ### After Looking how the data is organice is better to set up ideas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107726 entries, 0 to 107725
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             107726 non-null  object
#  1   rideable_type       107726 non-null  object
#  2   started_at          107726 non-null  object
#  3   ended_at            107726 non-null  object
#  4   start_station_name  107726 non-null  object
#  5   start_station_id    107726 non-null  object
#  6   end_station_name    107445 non-null  object
#  7   end_station_id      107388 non-null  object
#  8   start_lat           107726 non-null  float64
#  9   start_lng           107726 non-null  float64
#  10  end_lat             107391 non-null  float64
#  11  end_lng             107391 non-null  float64
#  12  member_casual       107726 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 10.7+ MB

# %% [markdown]
# ###  Is really important to know which are your N/A columns and figure out why are N/A

# %%
df.isna().sum()
# Out:
# ride_id                 0
# rideable_type           0
# started_at              0
# ended_at                0
# start_station_name      0
# start_station_id        0
# end_station_name      281
# end_station_id        338
# start_lat               0
# start_lng               0
# end_lat               335
# end_lng               335
# member_casual           0
# dtype: int64

# %% [markdown]
# # Phase 2: Data Cleaning
# ### In this section, I will prepare the data for analysis by:
# ### 1. Converting data types (timestamps).
# ### 2. Creating new columns to help with analysis (duration, day of week).
# ### 3. Handling missing values (NaNs).
# ### 4. Removing logical outliers (trips that are too short or too long).

# %%
'''
Data Type Conversion
Convert `started_at` and `ended_at` to datetime objects.
Create a `duration_minutes` column.
The raw dataset has start/end times, but not the actual length of the trip. This is crucial for our analysis.
'''
# 1. Convert timestamp columns to datetime objects
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

# 2. Create a Duration Column (in Minutes)
df['duration_minutes'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60

# 3. Create 'Day of Week' and 'Hour' columns for temporal analysis
df['day_of_week'] = df['started_at'].dt.day_name()
df['start_hour'] = df['started_at'].dt.hour

# %%
# Verify the new columns were created correctly
df[['started_at', 'duration_minutes', 'day_of_week']].head()
# Out:
#                started_at  duration_minutes day_of_week
# 0 2025-07-13 21:07:32.221        365.041233      Sunday
# 1 2025-07-10 19:02:28.736         17.248800    Thursday
# 2 2025-07-04 14:02:35.827        105.469950      Friday
# 3 2025-07-18 14:46:32.568         13.172067      Friday
# 4 2025-07-13 10:49:03.936       1499.920583      Sunday

# %%
# Verify the data types are now correct
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# duration_minutes             float64
# day_of_week                   object
# start_hour                     int64
# dtype: object

# %%
# I will check which columns have missing data.

# Drop rows where start_station_name or end_station_name is missing
# We use 'inplace=True' to modify the dataframe permanently
df.dropna(subset=['start_station_name', 'end_station_name','end_lat', 'end_lng','end_station_id' ], inplace=True)

# after
df.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# duration_minutes      0
# day_of_week           0
# start_hour            0
# dtype: int64

# %%
#  See statistics BEFORE removing outliers
# Look at the 'min' and 'max' values here. 
display(df['duration_minutes'].describe())
# Out:
# count    107388.000000
# mean         10.324309
# std          26.211301
# min           1.001050
# 25%           4.143212
# 50%           6.398992
# 75%          10.300129
# max        1491.626817
# Name: duration_minutes, dtype: float64

# %%
# Count how many rows are actually outliers
# Trips < 1 minute or > 180 minutes (3 hours)
outliers = df[(df['duration_minutes'] < 1) | (df['duration_minutes'] > 180)]
print(f"Number of outliers: {len(outliers)}")
print(f"Percentage of dataset: {(len(outliers) / len(df)) * 100:.2f}%")
# Out:
# Number of outliers: 122
# Percentage of dataset: 0.11%

# %%
# Define criteria for keeping data
# Keep trips greater than 1 minute AND less than 180 minutes (3 hours)
clean_df = df[(df['duration_minutes'] > 1) & (df['duration_minutes'] < 180)]

# Update the main dataframe
df = clean_df

# Check stats after outlier removal
df['duration_minutes'].describe()
# Out:
# count    107266.000000
# mean          9.671618
# std          11.745566
# min           1.001050
# 25%           4.140504
# 50%           6.392467
# 75%          10.279833
# max         179.049917
# Name: duration_minutes, dtype: float64

# %% [markdown]
# ### Now that the data types are fixed, missing values are removed, and outliers are filtered, we check the final shape of the dataset to see how many records we retained for analysis.

# %%
df.shape
# Out:
# (107266, 16)

# %%
df.head()
# Out:
#              ride_id  rideable_type              started_at  \
# 6   8F19BE0DE5818EE7  electric_bike 2025-07-26 00:10:22.629
# 7   4D41624CF8121C30  electric_bike 2025-07-21 11:34:47.453
# 8   252C61A68D1A4D4D  electric_bike 2025-07-17 18:48:20.635
# 9   D17EAF8CB497AC0D  electric_bike 2025-07-26 17:55:39.234
# 10  CF2D4906BAF9DBF7   classic_bike 2025-07-14 15:01:40.049
#
#                   ended_at    start_station_name start_station_id  \
# 6  2025-07-26 00:28:00.524                Dey St            JC065
# 7  2025-07-21 11:45:21.076            Newark Ave            JC032
# 8  2025-07-17 19:04:21.382  River St & Newark St            HB106
# 9  2025-07-26 18:00:58.256  River St & Newark St            HB106
# 10 2025-07-14 15:13:38.036            Harborside            JC104
#
#     end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 6   Heights Elevator          JC059  40.737711 -74.066921  40.748716
# ...

# %% [markdown]
# ## Phase 3: Data Analysis & Visualization
# ### Now that the data is clean, I will answer 4 questions using aggregation and visualization.

# %% [markdown]
# ### Question 1: Peak Utilization Analysis
# ### What are the peak usage hours during weekdays versus weekends?

# %%
# Custom colors based on your preferred palette
custom_palette = ['#4B0082', '#FF1493'] # Dark Indigo and Deep Pink

# %%
#1. Create a "Weekend" vs "Weekday" column
df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])
df['day_type'] = df['is_weekend'].map({True: 'Weekend', False: 'Weekday'})

# %%
# 2. Aggregate: Count trips by Hour and Day Type
hourly_counts = df.groupby(['start_hour', 'day_type']).size().reset_index(name='trip_count')
hourly_counts.head()
# Out:
#    start_hour day_type  trip_count
# 0           0  Weekday         709
# 1           0  Weekend         644
# 2           1  Weekday         329
# 3           1  Weekend         505
# 4           2  Weekday         183

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=hourly_counts, x='start_hour', y='trip_count', hue='day_type', marker='o', palette=custom_palette)

plt.title('Peak Usage Hours: Weekdays vs. Weekends')
plt.xlabel('Hour of Day (0-23)')
plt.ylabel('Number of Trips')
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# ### As the results show, weekend hours are significantly greater than weekday hours.

# %% [markdown]
# ### Question 2: User Segmentation
# ### How does the average trip duration differ between Members and Casual users?

# %%
# 1. Aggregate: Calculate Average Duration by User Type
user_stats = df.groupby('member_casual')['duration_minutes'].mean().reset_index()

# Display the specific numbers
display(user_stats)
# Out:
#   member_casual  duration_minutes
# 0        casual         14.503881
# 1        member          7.971011

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=user_stats, x='member_casual', y='duration_minutes', palette=custom_palette)

plt.title('Average Trip Duration: Members vs. Casual Users')
plt.xlabel('User Type')
plt.ylabel('Average Duration (Minutes)')
plt.savefig('avg_duration_bar_chart_custom.png')

# %% [markdown]
# ### This result surprised me, as I initially expected members to use the bikes more frequently than casual riders. This insight suggests that offering discounts or additional benefits to members could encourage longer ride times an idea that could be valuable to offer customers.

# %% [markdown]
# ### Question 3: Station Imbalance Analysis
# ### Which stations have the highest "Start" vs. "End" disparity?

# %%
# 1. Count starts per station
starts = df['start_station_name'].value_counts().reset_index()
starts.columns = ['station_name', 'start_count']

# 2. Count ends per station
ends = df['end_station_name'].value_counts().reset_index()
ends.columns = ['station_name', 'end_count']

# 3. Merge the two frames
station_flow = pd.merge(starts, ends, on='station_name', how='outer').fillna(0)

# 4. Calculate Net Flow (Ends - Starts)
station_flow['net_flow'] = station_flow['end_count'] - station_flow['start_count']

# %%
# Get Top 5 
most_full = station_flow.nlargest(5, 'net_flow')
most_empty = station_flow.nsmallest(5, 'net_flow')

# Stations Accumulating Bikes (Need Trucks to Remove
display(most_full[['station_name', 'net_flow']])

#Stations Draining Bikes (Need Trucks to Refill
display(most_empty[['station_name', 'net_flow']])
# Out:
#                                 station_name  net_flow
# 2   Hoboken Terminal - Hudson St & Hudson Pl     482.0
# 0                              Grove St PATH     186.0
# 84                  Vesey Pl & River Terrace      41.0
# 12                           River St & 1 St      24.0
# 10                      Bergen Ave & Sip Ave      20.0
#                  station_name  net_flow
# 45            McGinley Square    -178.0
# 56                Oakland Ave    -178.0
# 71              Fairmount Ave    -117.0
# 24  Newark St & Washington St    -114.0
# 1        River St & Newark St    -111.0

# %%
# Visualization
plt.figure(figsize=(12, 6))
# Combine them for one plot
imbalance = pd.concat([most_full, most_empty])
sns.barplot(data=imbalance, x='net_flow', y='station_name', palette=custom_palette)
plt.title('Top 5 Most Imbalanced Stations (Net Flow)')
plt.xlabel('Net Flow (Arriving - Leaving)')
plt.ylabel('Station Name')
plt.axvline(0, color='black', linewidth=1)
plt.show()

# %% [markdown]
# ### Positive number = Bikes piling up (Net Accumulation)
# ### Negative number = Bikes draining away (Net Loss)
#
# ### The left station are the ones that constanly run out of bikes while the rigth are where everyone rides to.

# %% [markdown]
# ### Question 4: Route Popularity Analysis
# ### What are the most popular routes (Start to End)?

# %%
# 1. Create a Route column
df['route'] = df['start_station_name'] + " to " + df['end_station_name']

# 2. Count the routes
top_routes = df['route'].value_counts().head(10).reset_index()
top_routes.columns = ['route', 'trip_count']

# Top 10 Most Popular Commuter Routes
display(top_routes)
# Out:
#                                                route  trip_count
# 0                  Grove St PATH to Marin Light Rail         437
# 1  Hoboken Terminal - Hudson St & Hudson Pl to Ho...         410
# 2            McGinley Square to Bergen Ave & Sip Ave         390
# 3                Liberty Light Rail to Grove St PATH         385
# 4           Liberty Light Rail to Liberty Light Rail         380
# 5  Hoboken Ave at Monmouth St to Hoboken Terminal...         376
# 6                Grove St PATH to Liberty Light Rail         373
# 7                      Brunswick St to Grove St PATH         356
# 8                  Marin Light Rail to Grove St PATH         355
# 9            Bergen Ave & Sip Ave to McGinley Square         334

# %%
# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(data=top_routes, x='trip_count', y='route', palette=custom_palette)
plt.title('Top 10 Most Popular Routes')
plt.xlabel('Number of Trips')
plt.ylabel('Routes Start -> End ')
plt.show()

# %% [markdown]
# ### Business Value, Identifying these high-traffic corridors helps the city plan where to build protected bike lanes. It also helps Lyft know where to deploy users paid to move bikes to move inventory along these specific lines.

# %% [markdown]
# ### The route that end to close are people riding in circle just for fun or short commute.

# %% [markdown]
# # Conclusion :
#
# ### Infrastructure Planning: Identifying high-traffic corridors through data analysis assists the city in planning the construction of protected bike lanes.
#
# ### Operational Efficiency: The analysis helps Lyft determine where to deploy paid users to move bike inventory along specific high-demand lines.
#
# ### User Behavior: Routes where the start and end points are close together suggest that riders are either riding in circles for recreation or using the bikes for very short commutes.

# %% [markdown]
# ## Database Citation
# ### Source Data: The analysis uses the "JC-202507-citibike-tripdata.csv" dataset.
# ### Gemini.” Google, 17 Dec. 2025, gemini.google.com.
